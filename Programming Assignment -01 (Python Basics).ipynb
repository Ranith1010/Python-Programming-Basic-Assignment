# %%
#1.	Write a Python program to print "Hello Python"?

# %%
print("hello python")
# Out:
# hello python

# %%
#2.	Write a Python program to do arithmetical operations addition and division.?

# %%
a=8
b=9
sum =a+b   #ADDITON
print("sum of a and b is =",a+b)
Div = a/b  #DIVISION
print("a divided by b is = ", a/b)
# Out:
# sum of a and b is = 17
# a divided by b is =  0.8888888888888888

# %%
#3.	Write a Python program to find the area of a triangle?

# %%
b= 12
h= 20
Area = 1/2*b*h #AREA OF A TRIANGLE
print("Area of the triangle is = ",Area)
# Out:
# Area of the triangle is =  120.0

# %%
#4.	Write a Python program to swap two variables?

# %%
a=8
b=9
c=b
b=a      #SWAPPING TWO VARIABLES
a=c
print("new swapped value of a is = ",a)
print("new swapped value of b is ",b)
# Out:
# new swapped value of a is =  9
# new swapped value of b is  8

# %%
#5.	Write a Python program to generate a random number?

# %%
import random

number = random.randint(1,20) #random number
print("random number is =",number)
# Out:
# random number is = 1
